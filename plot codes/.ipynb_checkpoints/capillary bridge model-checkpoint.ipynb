# %%
import os
import seaborn as sns
import pandas as pd
import numpy as np
from datetime import datetime
import matplotlib.pyplot as plt

# %%
simu_folderpath = 'E:/Work/Surface Evolver/Data/Bubble_Bridge/20201006 model data final (af=2, l_d=10)/pin_radius_2 (fluid)/'

simu_df = pd.DataFrame()
with os.scandir(simu_folderpath) as folder:
    for file in folder:
        if file.is_file() and file.path.endswith( ('.txt') ) and file.name != 'rupture.txt':
            df_temp = pd.read_csv(file.path,delimiter='\t')
            #df_temp['ys/F'] = -1/(2*np.pi*df_temp['Force_Calc']) #inverse
            df_temp['File path'] = file.path
            simu_df = simu_df.append(df_temp)

simu_df['Simulation folder'] = simu_folderpath
simu_df['Force_actual'] = simu_df['Force_Calc']*2*np.pi
#simul_plot(simu_df)

# %%
sns.relplot(data=simu_df,
                 x = "Height",
                 y = "Force_Calc",
                 hue = "Bottom_Angle",
                 style = "Bottom_Angle",
                 kind = 'line',
                 markers = True,
                 dashes = False,
                 alpha = 0.8,
                 facet_kws={"legend_out": True})
plt.show()

# %%
simu_df.columns
# Out:
# Index(['Bottom_Angle', 'Pin_Radius', 'Elastic_Modulus', 'Aspect_Ratio',
#        'Ambient_Pressure', 'Height', 'Base_Height', 'Height_Final', 'Strain',
#        'Force', 'Force_Calc', 'Energy', 'Area', 'Scale', 'Volume', 'Pressure',
#        'Bottom_Length', 'Top_Length', 'Bottom_Area', 'Top_Area',
#        'Mean_Curvature', 'Min_Radius', 'Max_Radius', 'Pinning_Angle',
#        'Iterations', 'File path', 'Simulation folder'],
#       dtype='object')
